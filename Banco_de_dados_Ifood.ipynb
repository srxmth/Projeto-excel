# %% [markdown]
# <a href="https://colab.research.google.com/github/srxmth/Projeto-excel/blob/main/Banco_de_dados_Ifood.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mth = pd.read_excel('/content/drive/MyDrive/Analise de dados/mkt_data.xlsx')
mth
# Out:
#       Unnamed: 0   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0            0.0  58138.0      0.0       0.0     58.0     635.0       88.0
# 1            1.0  46344.0      1.0       1.0     38.0      11.0        1.0
# 2            2.0  71613.0      0.0       0.0     26.0     426.0       49.0
# 3            3.0  26646.0      1.0       0.0     26.0      11.0        4.0
# 4            4.0  58293.0      1.0       0.0     94.0     173.0       43.0
# ...          ...      ...      ...       ...      ...       ...        ...
# 2200      2200.0  61223.0      0.0       1.0     46.0     709.0       43.0
# 2201      2201.0  64014.0      2.0       1.0     56.0     406.0        0.0
# 2202      2202.0  56981.0      0.0       0.0     91.0     908.0       48.0
# 2203      2203.0  69245.0      0.0       1.0      8.0     428.0       30.0
# 2204      2204.0  52869.0      1.0       1.0     40.0      84.0        3.0
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# ...

# %%
mth_filter = mth

# %%
mth_filter
# Out:
#       Unnamed: 0   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0            0.0  58138.0      0.0       0.0     58.0     635.0       88.0
# 1            1.0  46344.0      1.0       1.0     38.0      11.0        1.0
# 2            2.0  71613.0      0.0       0.0     26.0     426.0       49.0
# 3            3.0  26646.0      1.0       0.0     26.0      11.0        4.0
# 4            4.0  58293.0      1.0       0.0     94.0     173.0       43.0
# ...          ...      ...      ...       ...      ...       ...        ...
# 2200      2200.0  61223.0      0.0       1.0     46.0     709.0       43.0
# 2201      2201.0  64014.0      2.0       1.0     56.0     406.0        0.0
# 2202      2202.0  56981.0      0.0       0.0     91.0     908.0       48.0
# 2203      2203.0  69245.0      0.0       1.0      8.0     428.0       30.0
# 2204      2204.0  52869.0      1.0       1.0     40.0      84.0        3.0
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# ...

# %%
mth_filter.duplicated().sum()
# Out:
# 0

# %%
mth_filter.describe()
# Out:
#         Unnamed: 0         Income      Kidhome     Teenhome      Recency  \
# count  2205.000000    2205.000000  2205.000000  2205.000000  2205.000000
# mean   1102.000000   51622.094785     0.442177     0.506576    49.009070
# std     636.672993   20713.063826     0.537132     0.544380    28.932111
# min       0.000000    1730.000000     0.000000     0.000000     0.000000
# 25%     551.000000   35196.000000     0.000000     0.000000    24.000000
# 50%    1102.000000   51287.000000     0.000000     0.000000    49.000000
# 75%    1653.000000   68281.000000     1.000000     1.000000    74.000000
# max    2204.000000  113734.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2205.000000  2205.000000      2205.000000      2205.000000
# mean    306.164626    26.403175       165.312018        37.756463
# std     337.493839    39.784484       217.784507        54.824635
# ...

# %%
mth_filter['Income'].hist()

# %%
sns.countplot(x=mth_filter['education_level'])

# %%
sns.countplot(x=mth_filter['marital_status'])

# %%
sns.boxplot(x=mth_filter['marital_status',y ='kids'])
# Out:
#   File "<ipython-input-31-ead970aea94e>", line 1
#     sns.boxplot(x=mth_filter['marital_status',y ='kids'])
#                                                 ^
# SyntaxError: invalid syntax

# %%
mth_filter.groupby(['marital_status'])['kids'].describe()
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# marital_status
# Divorced        230.0  1.008696  0.741716  0.0  1.0  1.0  1.0  3.0
# Married         854.0  0.967213  0.732019  0.0  0.0  1.0  1.0  3.0
# Single          477.0  0.859539  0.777289  0.0  0.0  1.0  1.0  3.0
# Together        568.0  0.980634  0.749823  0.0  0.0  1.0  1.0  3.0
# Widow            76.0  0.881579  0.747745  0.0  0.0  1.0  1.0  2.0

# %%
sns.boxplot(x=mth_filter['kids'],y=mth_filter['expenses'])

# %%
mth_filter.groupby(['kids'])['expenses'].mean()
# Out:
# kids
# 0.0    1041.207006
# 1.0     434.530576
# 2.0     221.568675
# 3.0     237.380000
# Name: expenses, dtype: float64

# %%
plt.scatter(mth_filter['expenses'], mth_filter['Income'])
